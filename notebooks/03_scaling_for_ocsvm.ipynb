# %% [markdown]
# Imports + Load encoded data

# %%
import pandas as pd
import numpy as np
import joblib
import os

from sklearn.preprocessing import StandardScaler

# %%
train_df = pd.read_csv("../data/processed/nsl_kdd_train_encoded.csv")
test_df  = pd.read_csv("../data/processed/nsl_kdd_test_encoded.csv")

print(train_df.shape, test_df.shape)
# Out:
# (125973, 125) (22544, 125)

# %% [markdown]
# Define columns and split X/y

# %%
drop_cols = ["attack_type", "difficulty", "label"]

X_train = train_df.drop(columns=drop_cols)
y_train = train_df["label"]

X_test  = test_df.drop(columns=drop_cols)
y_test  = test_df["label"]

print("X_train:", X_train.shape, "y_train:", y_train.shape)
print("X_test :", X_test.shape,  "y_test :", y_test.shape)
# Out:
# X_train: (125973, 122) y_train: (125973,)
# X_test : (22544, 122) y_test : (22544,)

# %% [markdown]
# Fit scaler on TRAIN only, transform both

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

print("Scaled shapes:", X_train_scaled.shape, X_test_scaled.shape)
# Out:
# Scaled shapes: (125973, 122) (22544, 122)

# %% [markdown]
# Save scaler + scaled arrays

# %%
os.makedirs("../models/preprocessing", exist_ok=True)

joblib.dump(scaler, "../models/preprocessing/standard_scaler.joblib")

np.save("../data/processed/X_train_scaled.npy", X_train_scaled)
np.save("../data/processed/X_test_scaled.npy", X_test_scaled)
np.save("../data/processed/y_train.npy", y_train.to_numpy())
np.save("../data/processed/y_test.npy", y_test.to_numpy())

print("Saved scaler + scaled arrays.")
# Out:
# Saved scaler + scaled arrays.
